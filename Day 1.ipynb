# %%
# single line comments

print ("Vaishnavi kalgapure")
print ("college of computer science and information technology latur")
print ("Bsc(cs)")
# Out:
# Vaishnavi kalgapure
# college of computer science and information technology latur
# Bsc(cs)

# %%
# multiline comments

# Task 1
print("Vaishnavi kalgapure")
# Out:
# Vaishnavi kalgapure

# %%
# Docstring

""" print("Vaishnavi kalgapure")
print("college of computer science and information technology latur")
print("Bcs(cs)")"""
# Out:
# ' print("Vaishnavi kalgapure")\nprint("college of computer science and information technology latur")\nprint("Bcs(cs)")'

# %%
# Task 2 indentation practice

print("Hello World")
print("Welcome to python")
# Out:
# Hello World
# Welcome to python

# %%
# Task 3 Variables Declaration

name="Vaishnavi kalgapure"
print(type(name))
age=21.
print(type(age))
height=5.2
print(type(height))
is_student=True 
print(type(is_student))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>

# %%
# Task 4 variable Naming rules

first_name ="Vaishnavi"
my_name ="Vaishnavi"
Total_amount =2000
Class ="Bsc(cs)"
score =84.00

# %%
# Task 5 Arithmatic Operator

A =20
B =30
print(A+B)
# Out:
# 50

# %%
# Task 6 Comparison opreators

y =26
Z =23
y==Z
# Out:
# False

# %%
# Task 7 Assignment Operators
a=10
a += 20
print(a)
# Out:
# 30

# %%
a=10
a -=12
print(a)
# Out:
# -2
