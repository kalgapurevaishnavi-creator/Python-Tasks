# %% [markdown]
# # Nested condition

# %%
#Task 1(Take a number as input. if the number is positive,check whether it is even or odd and print the result.

num=int(input("enter the number:"))
if num>30:
    print("positive")
    if num>40:
        print("odd")
    else:
        print("even")
# Out:
# enter the number: 55
# positive
# odd

# %%
#Task 2(Take a age as input. if age is greater than or equal to 18, check if the person is a senior citizen(age>=60) or adult.

age=int(input("enter the age:"))
if age>=18:
    print("senior citizen")
    if age>=60:
        print("junior citizen")
    else:
        print("adult")
# Out:
# enter the age: 77
# senior citizen
# junior citizen

# %%
#Task 3(Take a single charachter. if it is an alphabet,check whether it is uppercase or lowercase.

ch=input("Enter the Charachter:")
if ch.isalpha():
    if ch.isupper():
        print(" ch is in uppercase")
    else:
        print("lowercase")
else:
        print("No case")
# Out:
# Enter the Charachter: vaishu
# lowercase

# %%
#Task 4(take a three numbers as input and print the largest number using nested if statement(without using max())
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if a>b:
    print("largest=",a)
    if a>c:
        print("largest=",c)
    else:
    
        if a>c:
            print("lagest=", b)
        else:
            print("largest=",c)
# Out:
# enter the first number: 11
# enter the second number: 9
# enter the third number: 5
# largest= 11
# largest= 5

# %%
#Task 5 (take student marks. if marks>=40(pass), then further check if marks>=75 to print"pass with Distinction"

marks=int(input("enter the student marks:"))
if marks>=40:
    print("pass")
    if marks>=75:
        print("pass with Distinction")
    else:
        print("Fail")
# Out:
# enter the student marks: 86
# pass
# pass with Distinction

# %%
#Task 6(take a number.if it is divisible by 2,check if it is also divisible by 4.

num=int(input("enter the number:"))
if num/2:
    print("yes")
    if num/4:
        print("divisible by four")
    else:
        print("no")
# Out:
# enter the number: 20
# yes
# divisible by four

# %%
#Task 7(take a username and password. if username is"admin",then check if the password is correct.

username=input("enter the username:")
password=input("enter the password:")
if username=="admin":
    if password=="admin12345":
        print("login successful")
    else:
        print("wrong password")
    
else:
        print("invalid username")
# Out:
# enter the username: admin
# enter the password: admin12345
# login successful

# %%
#Task 8(take three side of triangle. first check if they from valid triangle, then check if it is Equilateral,isosceles or scalene.

a=int(input("enter side1:"))
b=int(input("enter side2:"))
c=int(input("enter side3:"))
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("equialateral")
    elif a==b or b==c or a==c:
        print("isosceles")
    else:
        print("scalene")
else:
    print("invalid trangle")
# Out:
# enter side1: 33
# enter side2: 66
# enter side3: 66
# isosceles

# %%
#Task 9(take salary and year of expriance.if salary>50000,check experience to decide"Manager" or "senior Manager"

salary=int(input("enter the salary:"))
years=int(input("enter the years:"))
if salary>50000:
    print("Manager")
else:
    print("seniour manager")
# Out:
# enter the salary: 400000
# enter the years: 2020
# Manager

# %%
#Task 10(take a charachter.if it is a letter,check if it is vowel or consonant.if it is a digit,print
#"Digit".else print"special charachter".

ch=input("Enter the charachter:")
if ch.isalpha():
    if ch.lower() in "aeiou":
      print("vowel")
    else:
        print("Consonant")
elif ch.isdigit():
        print("Digit")
  
else:
    print("Special charachter")
# Out:
# Enter the charachter: vaishu
# Consonant

# %%
#Task 11( take a year as input.check if it is a leap years using nested conditions.

year=int(input("enter the year:"))
if year%400==0 and year%4==0:
    print("leap year")
    if year%!=100:
        print("leap")
    else:
        print("no leap year")
# Out:
# enter the year: 2000
# leap year
# leap

# %%
#Task 13(take three number.check it all three are a equal ,or any two are equal using nested if.

a=11
b=22
c=55
if a>b and a>c:
    print("equael")
elif b>a and b>c: 
    print("lregat equael")
else:
    print("not equal")
# Out:
# not equal

# %%
#Task 14(take a number. if it is posible and even,print "positive even"Number"
num=int(input("enter the number:"))
if num>20:
    print("positive")
    if num<70:
        print("greastest")
    else:
        print("negative")
# Out:
# enter the number: 33
# positive
# greastest

# %%
#Task 15(take marks of 5 subjects.if average>=60,then check if all subjects are above 40 marks.

sub1=int(input("enter the first marks:"))
sub2=int(input("enter the second marks:"))
sub3=int(input("enter the third marks:"))
sub4=int(input("enter the four marks:"))
sub5=int(input("enter the fifth marks:"))
avg=(sub1+sub2+sub3+sub4+sub5)/5
if avg>=60:
    if sub1>40 and sub2>40 and sub3>40 and sub4>40 and sub5>40:
       print("excelent")
    else:
       print("average 40")
else:
    print("average is below 60")
# Out:
# enter the first marks: 66
# enter the second marks: 66
# enter the third marks: 77
# enter the four marks: 88
# enter the fifth marks: 88
# excelent

# %%
#Task 16(take username,password,and age.if username and password are correct and age>18,print "login successful".Else if age<18,print age restriction 
#message.

username=int(input("enter the username:"))
password=int(input("enter the password:"))
age=int(input("enter the age:"))
if age>=18:
    print("login sucessful")
    if username!=password:
        print("login failed")
    else:
        if age<18:
            print("age restriction")
# Out:
# enter the username: 555
# enter the password: 777
# enter the age: 21
# login sucessful
# login failed

# %%
#Task 17( take a number.check if is divisible by both 3 and 5 using nested if.

num=int(input("enter the number:"))
if num/3:
    print("3 is divisible")
    if num/5:
        print("5 is divisible")
    else:
        print("both are not divisible")
# Out:
# enter the number: 30
# 3 is divisible
# 5 is divisible

# %%
#Task 18(take three sides of triangle.check if valid,then check if it is a right-angled
#triangle using pythagoras theorem.

s1=int(input("enter the first triangle:"))
s2=int(input("enter the second triangle:"))
s3=int(input("enter the third triangle:"))
if s1>s2:
    print("s1 is valid")
    if s3>s1:
        print("s3 is valid")
    else:
        print("both are not valid")
# Out:
# enter the first triangle: 22
# enter the second triangle: 11
# enter the third triangle: 55
# s1 is valid
# s3 is valid

# %%
#Task 19( take a grade(A,B,C,D,F) and print full description using if-elif-else(Excellent, Good average,etc)

A=int(input("enter the A grade:"))
B=int(input("enter the B grade:"))
C=int(input("enter the C grade:"))
D=int(input("enter the D grade:"))
F=int(input("enter the F grade:"))
if A>B:
    print("Excellent")
    if A>C:
        print("A is Excellent")
    elif B>C:
        print("good")
    if A>D:
        print("average")
    else:
        print("failed")
# Out:
# enter the A grade: 333
# enter the B grade: 55
# enter the C grade: 55
# enter the D grade: 66
# enter the F grade: 77
# Excellent
# A is Excellent
# average

# %%
#Task 20(Take income.if income>10000,check tax slab.if income between 50000-10000,different slab. Else print"Low income".
income=int(input("enter the income:"))
if income>10000:
    print("tax slab")
    if income>50000:
        print("slab")
    else:
        print("low income")
# Out:
# enter the income: 20000
# tax slab
# low income
