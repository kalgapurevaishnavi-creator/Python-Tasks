# %%
# Task 1

user ="Vaishnavi"
print(user[5:])
# Out:
# navi

# %%
a ="Chandrakant"
print(a[0:-5])
# Out:
# Chandr

# %%
A ="Vaishnavi kalgapure"
print(A[2:8])
# Out:
# ishnav

# %%
num1="Vanita"
print(num1[2])
# Out:
# n

# %%
# Task 4

Name="Vaishnavi  Chandrakant Kalgapure"
print( Name[0:10])
print( Name[-0:-1])
# Out:
# Vaishnavi
# Vaishnavi  Chandrakant Kalgapur

# %%
s="vaishnavi"
print(s.upper())
print(s.lower())
print(s.title())
# Out:
# VAISHNAVI
# vaishnavi
# Vaishnavi

# %%
# Task 7

s=input("Vaishnavi")
s.title()
# Out:
# Vaishnavi Vaishnavi
# 'Vaishnavi'

# %%
# Task 8
s="Vaishnavi"
s.lower()
s.upper()
# Out:
# 'VAISHNAVI'

# %%
# Task 9

text="Vaishnavi"
text.isalpha()
# Out:
# True

# %%
text="Vaishnavi233"
text.isalpha()
# Out:
# False

# %%
# Task 10

text="122333"
text.isdigit()
# Out:
# True

# %%
text="Vai1234"
text.isdigit()
# Out:
# False

# %%
text="Vaishnavi"
text.isalnum()
# Out:
# True

# %%
text="1200003"
text.isalnum()
# Out:
# True

# %%
# task 12
text="Kalgapure"
text.islower()
# Out:
# False

# %%
text="kalgapure"
text.islower()
# Out:
# True

# %%
#Task 13

a=input("Vaishnavi")
print(a[8:4])
print("Valid a")
print("invalid a")
# Out:
# Vaishnavi 5
# Valid a
# invalid a

# %%
# Task 14

s="Vaishnavi is easy"
print(s.find("s"))
# Out:
# 3

# %%
s="vaishnavi is easy"
print(s.find("b"))
# Out:
# -1

# %%
#Task 15

s=input("Enter a string:")
word=input("Enter the word:") 

if s.find(word)!= -1:
   print("word found")
else:
   print(-1)
# Out:
# Enter a string: 5
# Enter the word: 6
# -1

# %%
#Task 16


a="my name is vaishnavi"

print(a.find("b"))
pos=a.index("m")
print("position:",pos)
# Out:
# -1
# position: 0

# %%
# Task 17

s="my name is Vaishnavi"
print (s.find("z"))
print (s.index("a"))
# Out:
# -1
# 4

# %%
#Task 18


name="Vaishnavi Chandrakant Kalgapure"
print(name.upper())
# Out:
# VAISHNAVI CHANDRAKANT KALGAPURE

# %%
#Task 19



s=input("Enter the number:")
s.isdigit()
# Out:
# Enter the number: vaishu
# False

# %%
# Task 20


Title="Vaishnavi"
print(Title)
# Out:
# Vaishnavi
