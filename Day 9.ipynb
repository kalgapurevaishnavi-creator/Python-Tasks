# %% [markdown]
# ### if,if-else,and if-elif-else statements

# %% [markdown]
# #

# %%
#Task 1(create a program to check if a number is positive or negative.

num=int(input("enter the number:"))
if num>=25:
    print("number is positive")
else:
    print("number is negative")
# Out:
# enter the number: 33
# number is positive

# %%
#Task 2(take age as input if age is grater than or equal to 18,print"you can vote"


num=int(input("enter the age:"))
if num>=18:
    print("you can vote")
else:
    print("not vote")
# Out:
# enter the age: 22
# you can vote

# %%
#Task 3(take two numbers and print the larger one using if-else

a=2
b=30
if a<=b:
    print("larger number")
else:
    print("smaller number")
# Out:
# larger number

# %%
#Task 4(check if a given number is even or odd

num=int(input("enter the number:"))
if num>=21:
    print("even")
else:
    print("odd")
# Out:
# enter the number: 33
# even

# %%
#Task 5(take a character and check if it is 'A' or not

ch=input("enter the charachter:")
if ch.upper()=="A":
    print("yes")
else:
    print("no")
# Out:
# enter the charachter: radha
# no

# %%
#Task 6(Take marks and print"pass"if marks>=40,otherwise "fail"

marks=int(input("enter the marks:"))
if marks>=40:
    print("pass")
else:
    print("fail")
# Out:
# enter the marks: 55
# pass

# %%
#Task 7(check if a number is divisible by 5

num=int(input("enter the number:"))
if num/5 or num!=5:
    print("yes")
else:
    print("no")
# Out:
# enter the number: 20
# yes

# %%
#Task 8(take a number and print whether it is positive ,negative,or zero.

num=int(input("Enter the number:"))
if num > 0:
    print("positive")
elif num < 0:
    print("Negative")
else:
    print("zero")
# Out:
# Enter the number: 3
# positive

# %%
#Task 9(Take three numbers and print the largest number using if-elif-else

a=33
b=44
c=22
if a>b or a<b:
    print("largest")
elif b>a or b<a:
    print("largest")
else:
    print("no largest")
# Out:
# largest

# %%
#Task 10(Take a year and check if it is a leap year(div by 4 but not 100,or div by 400)

year=int(input("enter the year:"))
if (year%400==0)or(year%4==0 and year%100!=0):
    print("leap year")
else:
    print("not leap year")
# Out:
# enter the year: 2222
# not leap year

# %%
#Task11(Take a character and check if it is a vowel(a,e,i,o,u) or consonant.


ch=input("Enter the character:").lower()
if (ch=='a'or ch=='e'or ch=='i'or ch=='o'or ch=='u'):
   print("vowel")
else:
   print("consonant")
# Out:
# Enter the character: vaishu
# consonant

# %%
#Task 13(take temperature in celsius.if>30 print"Hot",20-30 print"Warm",<20 print"cold".

temp=int(input("Enter the temperature:"))
if temp>30:
    print("Hot")
elif 20<=temp<=30:
    print("Warm")
else:
    print("cold")
# Out:
# Enter the temperature: 11
# cold

# %%
#Task 12(take salary as input.if salary>50000 print "High",elif salary> 30000 print
#"Mediam",else print"Low"

salary=int(input("Enter the salary:"))
if salary>50000:
    print("High")
elif salary>30000:
    print("Mediam")
else:
    print("Low")
# Out:
# Enter the salary: 22222
# Low

# %%
#Take 14(Take username and password.if both correct print"Login successful",else print"logiin Failed".

username=input("Enter the username:")
password=input("Enter the password:")
if username==password or password!=username:
    print("Login successful")
else:
    print("Login Failed")
# Out:
# Enter the username: 333
# Enter the password: 555
# Login successful

# %%
#Task 15(Take three sides of a triangle.check if they from a valid triangle.if
#yes,also print if it is Equilateral,lsosceles,or Scalene.

tr1 =int(input("enter the first Triangle:"))
tr2=int(input("enter the second Triangle:"))
tr3=int(input("enter the third Triangle:"))
if tr1+tr2>tr3 and tr1+tr3>tr2 and tr2+tr3>tr1:
    print("Valid Triangle")
    if tr1==tr2==tr3:
       print("Equilateral Triangle")
    elif tr1==tr2 or tr2==tr3 or tr1==tr3:
       print("Isosceles Triangle")
    else:
       print("Scalene Triangle")
else:
    print("Invalid Triangle")
# Out:
# enter the first Triangle: 22
# enter the second Triangle: 22
# enter the third Triangle: 22
# Valid Triangle
# Equilateral Triangle

# %%
#Task 16(Take student marks in 5 subjects.calculate pecentage and give grade:90+A,80-89:A,70-79:B,60-69:c,below 60 fail.


stu1=int(input("enter the first marks:"))
stu2=int(input("enter the second marks:"))
stu3=int(input("enter the third marks:"))
stu4=int(input("enter the fourth marks:"))
stu5=int(input("enter the fifth marks:"))
total=stu1+stu2+stu3+stu4+stu5
pecentage = total/5

if pecentage>=90:
    print("Grade:A+")
elif pecentage>=80:
    print("Grade:A")
elif pecentage>=70:
    print("Grade:B")
elif pecentage>=60:
    print("c")
else:
    print("Fail")
# Out:
# enter the first marks: 33
# enter the second marks: 33
# enter the third marks: 44
# enter the fourth marks: 55
# enter the fifth marks: 66
# Fail

# %%
#Task 17(take a number. check if it is divisible by both 3 and 5.if yes print"FizzBuzz",by 3 print"Fizz",by 5 print
#"Buzz",else print the number

num=int(input("enter the number:"))
if num % 3 and num % 5:
    print("FizzBuzz")
elif num % 3:
    print("Fizz")
elif num % 5:
    print("Buzz")
else:
    print("num")
# Out:
# enter the number: 3
# Buzz

# %% [raw]
# #Task 18(take a age and gender.if age>=18 and gender is "Male" print"Eligible for "Army",
# #elif age>=18 and gender"Femele" print"Eligible for other Service",else print"Not Eligible".
#
# age=int(input("Enter the age:"))
# gender=input("Enter the gender:").lower()
# if age>=18 and gender =="Male":
#     print("Eligible for Army")
# elif age>=18 and gender =="female":
#     print("Eligible for other service")
# else:
#     print("Not Eligible")

# %%
#Task19(take a charachter. check if it is uppercase,lowercase,digit,or special charachter

a=22
b=11
if a>b:
    print("uppercase")
elif a<b:
    print("lowercase")
else:
    print("digit")
# Out:
# uppercase

# %%
#Task 20(take three number.print them in asending order using if-elif-else(without using (without using sort()

a=10
b=20
c=30
if a<=b and b<=c:
    print(a,b,c)
elif a<=c and c<=b:
    print(a,c,b)
elif b<=a and b<=b:
    print(b,a,c)
elif b<=c and c<=a:
    print(b,c,a)
elif c<=a and a<=b:
    print(c,a,b)
else:
    print(c,b,a)
# Out:
# 10 20 30

# %% [markdown]
# # Task no 2

# %%
#flow control

# %% [markdown]
# ### Task no1(write a program check whether a number is positive , negative,or zero
#
# num=int(input("enter the number:"))
# if num>0:
#     print("positive")
# elif num<0:
#     print("Negative")
# else:
#     print("Zero")

# %%
#Task 2(Write a program to check whether a person can enter a movie theater
#(Age must be 18 or above

num=int(input("Enter the age:"))
if num>18:
    print(" movie theater")
elif num<18:
    print("no movie")
else:
    print("no")
# Out:
# Enter the age: 11
# no movie

# %%
#Task 3(write a program to check whether a number is divisible by 2.
num=int(input("enter the number:"))
if num % 2==0:
    print("yes")
else:
    print("No")
# Out:
# enter the number: 7
# No

# %%
#Task 4(write a program to compare two numbers and print the greater number.
a=10
b=33
if a==b:
    print("greater number")
else:
    print("lessthan number")
# Out:
# lessthan number

# %%
#Task 5(write a program to check whether a character is uppercase or lowercase.

ch=input("enter the character:")
if ch>='A' and ch<='Z':
    print("uppercase")
elif ch>='a' and ch<='z':
    print("lowercase")
else:
    print("Not an alphabet")
# Out:
# enter the character: aaaaaaa
# lowercase

# %%
#Task 6(write a program to check whether a year is a leap year or not.

year=int(input("enter the year:"))
if (year%400==0) or (year%4==0 and year%100!=0):
    print("leap year")
else:
    print("no leap year")
# Out:
# enter the year: 2222
# no leap year

# %%
#Task 7(write a program to display.
#Morning" if time<12
#Afternoon"if time between 12 and 5
#Evening"otherwise

time=int(input("enter the  time:"))
if time<12:
    print("Morning")
elif time<=17:
    print("Afternoon")
else:
    print("Evening")
# Out:
# enter the  time: 12
# Afternoon

# %%
##### Task 8(write a program to check whether a student passed with distinction
# 75+ Distinction
#35-74 pass
#below 35 fail
mark=int(input("enter the marks:"))
if mark>=75:
    print("Distinction")
elif mark>=35:
    print("pass")
else:
    print("fail")
# Out:
# enter the marks: 54
# pass

# %%
#Task 9(
