# %%
keys=["A","B","c"]
Dict3 = dict.fromkeys(keys,10)
Dict3
# Out:
# {'A': 10, 'B': 10, 'c': 10}

# %% [markdown]
# # Dictionary and tuple

# %%
# Task 1

students={"Name":"Vaishnavi","age":21,"City":"Pune"}
print(students)
# Out:
# {'Name': 'Vaishnavi', 'age': 21, 'City': 'Pune'}

# %%
# Task 2

d={"a":1,"b":2,"c":3}
print(d.keys())
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# Task 3

d={"a":1,"b":2}
print(d.values())
# Out:
# dict_values([1, 2])

# %%
# Task 4

d={"name":"sumit","age":25}
print(d.get("sumit"))
# Out:
# None

# %%
# Task 5

d=(10,20,44,55,33)
print(type(d))
print(len(d))
# Out:
# <class 'tuple'>
# 5

# %%
# Task 6

tup=(10,20,30,40,50)
tup.count(20)
# Out:
# 1

# %%
# Task 7

tup=(10,20,30,40)
tup.index(30)
# Out:
# 2

# %%
# Task 8

dicts={}
dicts={"Name":"Vaishnavi"}
dicts={"age": 21}
dicts={"city":"pune"}
dicts
# Out:
# {'city': 'pune'}

# %%
# Task 9

d={"a":1,"b":2}
d.update({"c":3,"d":4})
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Task 10

students={"name":"Rahul","age":22,"city":"Delhi"}
students.pop("age")
print(students)
# Out:
# {'name': 'Rahul', 'city': 'Delhi'}

# %%
# Task 11
d={"x":10,"y":20,"z":30}
d.popitem()
print(d)
# Out:
# {'x': 10, 'y': 20}

# %%
# Task 12

dicts={"a":1,"b":2}
print(dicts)
print(dicts.copy())
# Out:
# {'a': 1, 'b': 2}
# {'a': 1, 'b': 2}

# %%
# Task 13

keys=["red","green","blue"]
d= d.fromkeys(keys,0)
print(d)
# Out:
# {'red': 0, 'green': 0, 'blue': 0}

# %%
# Task 14
tup=(2.2,44,66,66,74)
print(type(tup[4]))
# Out:
# <class 'int'>

# %%
# Task 15

d={"name":"sumit"}
d.setdefault("age",25)
print(d)
# Out:
# {'name': 'sumit', 'age': 25}

# %%
# Task 16

dicts={"Name":"V","age":3,"city":"pune"}
dicts.update()
dicts.popitem()
print(dicts)
# Out:
# {'Name': 'V', 'age': 3}

# %%
# Task 17

tup=(23,33,44,55,66,77)
print(tup.index(44))
print(tup.count(33))
# Out:
# 2
# 1

# %%
# Task 18

student={}
Name1=input("enter first student name:")
marks1=int(input("enter first student marks:"))
student[Name1]=marks1
Name2=input("enter second student name:")
marks2=int(input("enter second student marks:"))
student[Name2]=marks2
Name3=input("enter the student name:")
marks3=int(input("enter third student marks:"))
student[Name3]=marks3
print(student)
# Out:
# enter first student name: UHBYG
# enter first student marks: 988
# enter second student name: UHBHUB
# enter second student marks: 0987
# enter the student name: JGVFGC
# enter third student marks: 9867
# {'UHBYG': 988, 'UHBHUB': 987, 'JGVFGC': 9867}

# %%
# Task 19

data={"a":10,"b":20,"c":10}
data.items()
# Out:
# dict_items([('a', 10), ('b', 20), ('c', 10)])

# %%
#Task 20

dicts={"Name":"aru","age":22,"city":"pune"}
print(dicts.copy())
print(dicts.clear())
# Out:
# {'Name': 'aru', 'age': 22, 'city': 'pune'}
# None

# %%
# Task 21


student={"name":"Aman","age":21,"city":"pune","marks":85}
student.update({"course":"python"})
print(student)
student.popitem()
print(student)
student.items()
print(student)
# Out:
# {'name': 'Aman', 'age': 21, 'city': 'pune', 'marks': 85, 'course': 'python'}
# {'name': 'Aman', 'age': 21, 'city': 'pune', 'marks': 85}
# {'name': 'Aman', 'age': 21, 'city': 'pune', 'marks': 85}

# %%
# Task 22

tup=(10,11,12,13,14,15,16,17)
num=12
num=int(input(tup))
print("index =",tup.index(num))
print("count =",tup.count(num))
print("no not found")
lst=list(tup)
lst.sort(reverse=True)
print("Desending list =",lst)
# Out:
# (10, 11, 12, 13, 14, 15, 16, 17) 12
# index = 2
# count = 1
# no not found
# Desending list = [17, 16, 15, 14, 13, 12, 11, 10]

# %%
#Task 23

students= {}
name=input("enter students name:")
marks=int(input("enter students marks:"))
students[name]=marks
highest =max(students,key=students.get)
print("higest marks the students:",highest)
print("marks:",students[highest])
# Out:
# enter students name: vaishu
# enter students marks: 66
# higest marks the students: vaishu
# marks: 66

# %%
#Task 24

info={"name":"Aman","age":21,"city":"Mumbai"}
info.copy()
info["country"]="india"
print(info)
# Out:
# {'name': 'Aman', 'age': 21, 'city': 'Mumbai', 'country': 'india'}

# %%
#Task 25

data=(10,20,30,20,50)
result ={}
for num in data:
    result[num] =data.count(num)
print(result)
# Out:
# {10: 1, 20: 2, 30: 1, 50: 1}
