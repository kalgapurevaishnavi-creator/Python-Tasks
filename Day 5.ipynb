# %%
#Task 1

name=["radha","reva","kaviya","vaishu","arohi"]
print(name)
# Out:
# ['radha', 'reva', 'kaviya', 'vaishu', 'arohi']

# %%
# Task 2

numbers=[10,20,30,40,50]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
# Task 3

list=[]
list.append(3)
print(list)
# Out:
# [3]

# %%
#Task 4

lst=[1,2,3]
lst.extend([4,5,6])
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Task 5

lists=[10,20,30,40]
lists.insert(2,100)
print(lists)
# Out:
# [10, 20, 100, 30, 40]

# %%
#Task 6

lists=[10,20,50,30,5]
lists.remove(50)
print(lists)
# Out:
# [10, 20, 30, 5]

# %%
# Task 7

lst=[5,10,15,20]
lst.pop(3)
print(lst)
# Out:
# [5, 10, 15]

# %%
# Task 8

data=[1,2,3,4,5]
data.clear()
print(data)
# Out:
# []

# %%
# Task 9

lists=[10,15,25,30,40]
lists.index(25)
# Out:
# 2

# %%
# Task 10

lists=[7,2,7,5,7,8]
lists.count(7)
# Out:
# 3

# %%
# Task 11

lists=[45,12,78,23,56]
lists.sort()
print(lists)
# Out:
# [12, 23, 45, 56, 78]

# %%
#Task 12

lists=[45,12,78,56]
lists.sort(reverse=True)
print(lists)
# Out:
# [78, 56, 45, 12]

# %%
# Task 13
fruits=["apple","banana","mango","orange"]
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
# Task 14

lists=[1,2,3,4]
lists.copy()
print(lists)
# Out:
# [1, 2, 3, 4]

# %%
# Task 15

user=input("Enter a sentence:")
words=user.split()
print(user)
# Out:
# Enter a sentence: i love python programming
# i love python programming

# %%
# Task 16

lists=[20,30,40,50,60]
num=[1,2,3]
lists.append(3)
lists.sort()
print(lists)
# Out:
# [3, 20, 30, 40, 50, 60]

# %%
# Task 17

lists=["apple","banana","orange"]
lists.insert(0,"python")
lists.pop()
print(lists)
print(len(lists))
# Out:
# ['python', 'apple', 'banana']
# 3

# %%
# Task 18

city=["p","m","n","s"]
city.reverse()
print(city)
# Out:
# ['s', 'n', 'm', 'p']

# %%
# Task 19

data=[10,20,30,20,40,20]
data.remove(20)
data.remove(20)
data.remove(20)
print(data)
# Out:
# [10, 30, 40]

# %%
# Task 20

marks=[20,40,60,44]
marks.sort()
print(marks)
print(marks[0])
print(marks[-1])
# Out:
# [20, 40, 44, 60]
# 20
# 60
