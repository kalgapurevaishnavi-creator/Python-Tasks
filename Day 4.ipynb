# %%
#Task 1

s=input("Enter the  value")
s.replace(" ","_")
# Out:
# Enter the  value vaishu abc
# 'vaishu_abc'

# %%
#Task 2

a=input("Enter the value")
a.rstrip()
a.lstrip()
# Out:
# Enter the value vaishnavi kalgapure
# 'vaishnavi kalgapure'

# %%
#Task 3

text="my name is Vaishnavi"
text.startswith("hello")
# Out:
# False

# %%
# Task 4

text="my name is vaishnavi"
text.endswith(".com")
# Out:
# False

# %%
#Task 5

text="Appple,Banana,Grapes"
text.split(",")
# Out:
# ['Appple', 'Banana', 'Grapes']

# %%
#Task 6

fruits="Apple,Banana,Mango,Grapes"
" ".join(fruits)
# Out:
# 'A p p l e , B a n a n a , M a n g o , G r a p e s'

# %%
#Task 7

lists=[" python "," is "," awesome "]

list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()

("-".join(lists))
# Out:
# ' python - is - awesome '

# %%
# Task 8

name="Vaishnavi Chandrakant Kalgapure"
words=name.split()
print("First name:",words[0])
print("last name:",words[-1])
# Out:
# First name: Vaishnavi
# last name: Kalgapure

# %%
#Task 9

sentence=input("Enter the sentence:")
words=sentence.split()
print("Total words:",len(words))
# Out:
# Enter the sentence: my name is vaishnavi
# Total words: 4

# %%
#Task 10

email=input("Enter email:")
email.endswith("@gmail.com")
"yes"*(email.count("v")>=2) or "no"
# Out:
# Enter email: Kalgapure@gmail.com
# 'no'

# %%
#Task 11

text="hello world python"
text.replace("world","Everyone")
text.split()
# Out:
# ['hello', 'world', 'python']

# %%
#Task 12

n1=input("enter city name:")
n2=input("enter city name:")
n3=input("enter city name:")
n4=input("enter city name:")
n5=input("enter city name:")

c=[n1,n2,n3,n4,n5]

print("\n".join(c))
# Out:
# enter city name: l
# enter city name: y
# enter city name: u
# enter city name: k
# enter city name: m
# l
# y
# u
# k
# m

# %%
#Task 13

text="hello world"
text=text.strip()
text=text.title()
print(text)
print(text.startswith("hello"))
# Out:
# Hello World
# False

# %%
#Task 14

name="my name is Vaishnavi"
name = name.replace("Vaishnavi","Vaishu")

# %%
#Task 15

lists=["10","20","30","40"]
print("_".join(lists))
# Out:
# 10_20_30_40

# %%
a="my name"
a.split()
a.replace("_","         ")
" ".join(a)
# Out:
# 'm y   n a m e'
