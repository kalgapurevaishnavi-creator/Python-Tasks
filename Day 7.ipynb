# %% [markdown]
# # Sets and if statement

# %%
#Task 1 (create a set with num{1,2,3,2,4,1} and print it.what do you observe?)

sets={1,2,3,4,1}
sets
# Out:
# {1, 2, 3, 4}

# %%
 # Task 2 (create an empty set using correct syntax and 3 number using add()

a = set()
a.add(1)
a.add(2)
a.add(3)
print(a)
# Out:
# {1, 2, 3}

# %%
#Task 3(given s={10,20,30},add multiple elements[40,50,60] using add()

s={10,20,30}
s.add(40)
s.update([40,50,60])
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
#Task 4(remove element 20 from set={10,20,30,40}using remove()  and discard() show difference

s={10,20,30,40}
s.remove(20)
print(s)
s.discard(20)
print(s)
# Out:
# {40, 10, 30}
# {40, 10, 30}

# %%
# Task 5(create two sets A={1,2,3,4} and B={3,4,5,6} print union,intersection,and diffreence

A={1,2,3,4}
B={3,4,5,6}

print(A.union(B))

print(A.intersection(B))
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}

# %%
#Task 6(check if 25 is present in set s={0,0,30,40} using in keyword. 

s={10,20,30,40}
print(25 in s)
# Out:
# False

# %%
#Task 7(create a set from the list[1,2,2,3,4,4,5] and print its length

lists=[1,2,2,3,4,4,5]
s=set(lists)
print(len(lists))
# Out:
# 7

# %%
#Task 8(Take 5 numbers as input from user,store them in a set,and print unique numbers only.

num1 =int(input("enter first number"))
num2 =int(input("enter second number"))
num3 =int(input("enter third number"))
num4 =int(input("enter four number"))
num5 =int(input("enter fifth number"))
s={num1,num2,num3,num4,num5}

print(s)
# Out:
# enter first number 55
# enter second number 66
# enter third number 77
# enter four number 88
# enter fifth number 88
# {88, 66, 77, 55}

# %%
#Task 9(given two sets A={1,2,3} and B={3,4,5},print elements that are in A but not in B

A={1,2,3}
B={3,4,5}
A.difference(B)
# Out:
# {1, 2}

# %%
#Task 10(create a set and try to add a list[1,2,3]inside it.what happens?

A={11,22,33,44,55}
A.update([1,2,3])
print(A)
# Out:
# {33, 1, 2, 3, 22, 55, 11, 44}

# %%
# Task 11 (take age as input if age>=18,print"you are eligible to vote".


Vaishu=22
if age>=18: 
    print("you are eligible to vote")
# Out:
# you are eligible to vote

# %%
#Task 12(Take a number and check if it is positive,negitive,or zero using if-elif-else

num=int(input("enter a number:"))
if num> 0:
    print("positive number")
elif num< 0:
    print("Negative number")
else:
    print("Zero")
# Out:
# enter a number: 33
# positive number

# %%
#Task 13 (take two numbers and print the larger one using if-else


num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
if num1 > num2:
   print("first number is larger")
elif num2 > num1:
   print("second number is larger")
else:
   print("both number are equal")
# Out:
# enter first number: 55
# enter second number: 66
# second number is larger

# %%
#Task 14(

ch=input("enter a charachter:")

if ch =='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u':
    print("it is vowel")
else:
    print("it is counsonant")
# Out:
# enter a charachter: vaishu
# it is counsonant

# %%
#Task 15(

marks=int(input("enter the marks:"))
if marks>= 90:
    print("Grade:A")
elif marks>= 80:
    print("Grade:B")
elif marks>=70:
    print("Grade:c")
else:
    print("Fail")
# Out:
# enter the marks: 77
# Grade:c

# %%
#Task 16(

a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if a>=b and a>=c:
    print("largest number is:a")
elif b>=a and b>=c:
    print("largest number is:b")
else:
    print("largest number is:c")
# Out:
# enter the first number: 44
# enter the second number: 34
# enter the third number: 22
# largest number is:a

# %%
#task 17(

num=int(input("enter the number:"))
if num % 2==0 and num>50:
    print("Number is even and greater than 50")
else:
    print("Condition not stisfied")
# Out:
# enter the number: 55
# Condition not stisfied

# %%
#Task 18(

usernsme=input("enter the username:")
password=input("enter the password:")
if username=="admin" and password=="1234":
    print("login sucessful")
else:
    print("login Failed")
# Out:
# enter the username: admin
